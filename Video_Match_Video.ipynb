# %%
# !pip install --upgrade moviepy
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: moviepy in f:\anaconda\envs\py38\lib\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (1.24.3)
# Requirement already satisfied: imageio<3.0,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (2.32.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in f:\anaconda\envs\py38\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (10.0.1)
# Requirement already satisfied: setuptools in f:\anaconda\envs\py38\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (68.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2023.7.22)
# Requirement already satisfied: colorama in f:\anaconda\envs\py38\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# Requirement already satisfied: torch in f:\anaconda\envs\py38\lib\site-packages (2.1.0)
# Requirement already satisfied: torchvision in f:\anaconda\envs\py38\lib\site-packages (0.16.0)
# Requirement already satisfied: torchaudio in f:\anaconda\envs\py38\lib\site-packages (2.1.0)
# Requirement already satisfied: filelock in f:\anaconda\envs\py38\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in f:\anaconda\envs\py38\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in f:\anaconda\envs\py38\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in f:\anaconda\envs\py38\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in f:\anaconda\envs\py38\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in f:\anaconda\envs\py38\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in f:\anaconda\envs\py38\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in f:\anaconda\envs\py38\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in f:\anaconda\envs\py38\lib\site-packages (from torchvision) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda\envs\py38\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in f:\anaconda\envs\py38\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)

# %%
import json
import os
from moviepy.editor import *
from moviepy import *

# %%
# %cd C:\Users\user\Desktop\video-classification-3d-cnn-pytorch
# Out:
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch

# %%
def loadVideosToInfile1(folder):
    videos = os.listdir(folder)
    with open('input1', 'w') as inputfile:
        for v in videos:
            if v.split('.')[-1] == 'mp4':
                inputfile.write(v+'\n')
loadVideosToInfile1('../scrap0')

# %%
def loadVideosToInfile2(folder):
    videos = os.listdir(folder)
    with open('input2', 'w') as inputfile:
        for v in videos:
            if v.split('.')[-1] == 'mp4':
                inputfile.write(v+'\n')
loadVideosToInfile2('../scrap1')

# %%
# !python main.py --input input1 --video_root ../scrap0 --output ../output_features1.json --model resnet-34-kinetics-cpu.pth --mode feature --no_cuda
# Out:
# loading model resnet-34-kinetics-cpu.pth
# ../scrap0\apartments-dont-kill-people.mp4
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap0\apartments-dont-kill-people.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:09.13, start: 0.000000, bitrate: 205 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x800 [SAR 1:1 DAR 12:5], 71 kb/s, 23.76 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0000023227a7eb00] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x800 [SAR 1:1 DAR 12:5], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=3.7 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  161 fps=0.0 q=24.8 size=N/A time=00:00:06.71 bitrate=N/A speed=12.9x
# [out#0/image2 @ 0000023222c71b80] video:4299kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  219 fps=0.0 q=24.8 Lsize=N/A time=00:00:09.09 bitrate=N/A dup=2 drop=0 speed=13.2x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)

# %%
# !python main.py --input input2 --video_root ../scrap1 --output ../output_features2.json --model resnet-34-kinetics-cpu.pth --mode feature --no_cuda
# Out:
# loading model resnet-34-kinetics-cpu.pth
# ../scrap1\it-sweet-of-i-heard-in-the-shed-before.mp4
# ../scrap1\its-perfect.mp4
# ../scrap1\kind-of-work-girls-do.mp4
# ../scrap1\let-out-let-out-of-there.mp4
# ../scrap1\miss-moneypenny.mp4
# ../scrap1\what-done-your-daughter-doesnt-come-cheap.mp4
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap1\it-sweet-of-i-heard-in-the-shed-before.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:26.15, start: 0.000000, bitrate: 182 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x804 [SAR 1:1 DAR 160:67], 47 kb/s, 23.94 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 129 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000002794ddc8d40] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x804 [SAR 1:1 DAR 160:67], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=2.6 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  167 fps=0.0 q=24.8 size=N/A time=00:00:06.96 bitrate=N/A speed=13.3x
# frame=  340 fps=332 q=24.8 size=N/A time=00:00:14.18 bitrate=N/A speed=13.9x
# frame=  513 fps=337 q=24.8 size=N/A time=00:00:21.39 bitrate=N/A speed=  14x
# [out#0/image2 @ 0000027949902d40] video:9338kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  627 fps=316 q=24.8 Lsize=N/A time=00:00:26.10 bitrate=N/A dup=1 drop=0 speed=13.2x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap1\its-perfect.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:12.01, start: 0.000000, bitrate: 341 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x804 [SAR 1:1 DAR 160:67], 207 kb/s, 23.98 fps, 23.98 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : L-SMASH Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000002d6391e3080] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x804 [SAR 1:1 DAR 160:67], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : L-SMASH Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=3.2 size=N/A time=00:00:00.04 bitrate=N/A dup=1 drop=0 speed=2.08x
# frame=  160 fps=0.0 q=24.8 size=N/A time=00:00:06.67 bitrate=N/A dup=1 drop=0 speed=12.8x
# [out#0/image2 @ 000002d634858540] video:5060kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  288 fps=0.0 q=24.8 Lsize=N/A time=00:00:11.97 bitrate=N/A dup=1 drop=0 speed=13.2x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap1\kind-of-work-girls-do.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:09.01, start: 0.000000, bitrate: 532 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1032 [SAR 1:1 DAR 80:43], 396 kb/s, 23.98 fps, 23.98 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0000026f05fcb2c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1032 [SAR 1:1 DAR 80:43], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=5.1 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  121 fps=0.0 q=24.8 size=N/A time=00:00:05.04 bitrate=N/A speed=9.54x
# [out#0/image2 @ 0000026f003fdb80] video:6909kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  216 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.96 bitrate=N/A speed=9.79x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap1\let-out-let-out-of-there.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:08.05, start: 0.000000, bitrate: 542 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 408 kb/s, 23.85 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001c309d0c8c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=3.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  127 fps=0.0 q=24.8 size=N/A time=00:00:05.29 bitrate=N/A speed=9.69x
# [out#0/image2 @ 000001c3037dbec0] video:3800kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  193 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A dup=1 drop=0 speed=10.1x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap1\miss-moneypenny.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:11.01, start: 0.000000, bitrate: 439 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x816 [SAR 1:1 DAR 40:17], 300 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 131 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001ca1548f300] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x816 [SAR 1:1 DAR 40:17], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=6.7 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  141 fps=0.0 q=24.8 size=N/A time=00:00:05.88 bitrate=N/A speed=11.2x
# [out#0/image2 @ 000001ca1079eec0] video:9505kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  264 fps=0.0 q=24.8 Lsize=N/A time=00:00:10.96 bitrate=N/A speed=11.3x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ffmpeg version 2023-11-13-git-67a2571a55-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58. 32.100 / 58. 32.100
#   libavcodec     60. 33.100 / 60. 33.100
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../scrap1\what-done-your-daughter-doesnt-come-cheap.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.34.101
#   Duration: 00:00:35.03, start: 0.000000, bitrate: 179 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 46 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.51.100 h264_nvenc
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 00000218edfe5000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.33.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=2.2 size=N/A time=00:00:00.04 bitrate=N/A dup=1 drop=0 speed=2.64x
# frame=  251 fps=0.0 q=24.8 size=N/A time=00:00:10.46 bitrate=N/A dup=1 drop=0 speed=20.3x
# frame=  513 fps=505 q=24.8 size=N/A time=00:00:21.39 bitrate=N/A dup=1 drop=0 speed=  21x
# frame=  774 fps=510 q=24.8 size=N/A time=00:00:32.28 bitrate=N/A dup=1 drop=0 speed=21.3x
# [out#0/image2 @ 00000218ea6cc440] video:9063kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  840 fps=511 q=24.8 Lsize=N/A time=00:00:34.99 bitrate=N/A dup=1 drop=0 speed=21.3x
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)

# %%
file = open('../output_features2.json')
segments = json.load(file)
len(segments)
# Out:
# 6

# %%
for s in segments: print(s['video'])
# Out:
# it-sweet-of-i-heard-in-the-shed-before.mp4
# its-perfect.mp4
# kind-of-work-girls-do.mp4
# let-out-let-out-of-there.mp4
# miss-moneypenny.mp4
# what-done-your-daughter-doesnt-come-cheap.mp4

# %%
print(segments[0]['clips'][0].keys())
# Out:
# dict_keys(['segment', 'features'])

# %%
import numpy as np
import json

# %%
file1 = open('C:\\Users\\user\\Desktop\\output_features1.json')
segments1 = json.load(file1)
file2 = open('C:\\Users\\user\\Desktop\\output_features2.json')
segments2 = json.load(file2)

# %%
film1Features = []
for s in segments1[0]['clips']:
    film1Features.append(np.array(s['features']))

# %%
def find_best_range(films, sample_film_features):
    best_range_info = {
        'start': 0,
        'score': 100000000,
        'filmX_index': -1  
    }

    for filmX_index, filmX in enumerate(films):
        filmX_features = []
        for s in filmX['clips']:
            filmX_features.append(np.array(s['features']))

        for i in range(len(filmX_features) - len(sample_film_features)):
            distance = 0
            for j in range(len(sample_film_features)):
                d = np.linalg.norm(filmX_features[i + j] - sample_film_features[j])
                distance += d

            if distance < best_range_info['score']:
                best_range_info['start'] = i
                best_range_info['score'] = distance
                best_range_info['filmX_index'] = filmX_index

    return best_range_info

best_range_info = find_best_range(segments2, film1Features)
print(f"Best Range Start: {best_range_info['start']}")
print(f"Best Range Score: {best_range_info['score']}")
print(f"Best Range belongs to Film Index: {best_range_info['filmX_index']}")
# Out:
# Best Range Start: 10
# Best Range Score: 159.07908214117566
# Best Range belongs to Film Index: 0

# %%
from IPython.display import Video

def exportXVideo(XVideo, Samfeatures, best_range_info):
    tsfps = XVideo.fps
    tsFrameLength = 1 / tsfps
    nrFrames = len(Samfeatures) * 16
    startFrame = best_range_info['start'] * 16
    startTime = startFrame * tsFrameLength
    endTime = startTime + nrFrames * tsFrameLength
    try:
        X_Matched_sample_Video = XVideo.subclip(startTime, endTime)
        X_Matched_sample_Video.ipython_display()
        X_Matched_sample_Video.write_videofile("C:\\Users\\user\\Desktop\\scrap0\\apartments-dont-kill-people.mp4", audio_codec='aac')
    except Exception as e:
        print(f"Fail: {e}")
    return X_Matched_sample_Video

XVideo = VideoFileClip('../scrap1/its-perfect.mp4')
Samfeatures = film1Features
best_range_info = best_range_info
X_Matched_sample_Video = exportXVideo(XVideo, Samfeatures, best_range_info)
# Out:
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# Fail: Error in file ../scrap1/its-perfect.mp4, Accessing time t=12.05-12.10 seconds, with clip duration=12 seconds,

# %%
#Yeah it failed but somehow the latter part still works, Maybe that's because the video duration is not long enough
X_Matched_sample_Video.duration
# Out:
# 8.675333333333333

# %%
frame = X_Matched_sample_Video.get_frame(1)

# %%
from PIL import Image

# %%
Image.fromarray(frame,'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x804>
