# %%
# !pip install tensorflow
# !pip install pillow
# !pip install scipy
# !pip install matplotlib
import tensorflow as tf
import PIL
from PIL import Image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Dropout, Dense, Softmax)
from tensorflow.keras.applications import mobilenet as _mobilenet
import random
import os
import numpy as np
from subprocess import call
import scipy
import matplotlib.pyplot as plt
from matplotlib import cm
import math
from decimal import Decimal, localcontext
from pathlib import Path
# Out:
# Requirement already satisfied: tensorflow in f:\anaconda\envs\py38\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in f:\anaconda\envs\py38\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in f:\anaconda\envs\py38\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in f:\anaconda\envs\py38\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in f:\anaconda\envs\py38\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in f:\anaconda\envs\py38\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in f:\anaconda\envs\py38\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in f:\anaconda\envs\py38\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in f:\anaconda\envs\py38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in f:\anaconda\envs\py38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in f:\anaconda\envs\py38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in f:\anaconda\envs\py38\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in f:\anaconda\envs\py38\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\envs\py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anaconda\envs\py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\envs\py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in f:\anaconda\envs\py38\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in f:\anaconda\envs\py38\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in f:\anaconda\envs\py38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in f:\anaconda\envs\py38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# Requirement already satisfied: pillow in f:\anaconda\envs\py38\lib\site-packages (10.1.0)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# Requirement already satisfied: scipy in f:\anaconda\envs\py38\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in f:\anaconda\envs\py38\lib\site-packages (from scipy) (1.24.3)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# Requirement already satisfied: matplotlib in f:\anaconda\envs\py38\lib\site-packages (3.7.3)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in f:\anaconda\envs\py38\lib\site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in f:\anaconda\envs\py38\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in f:\anaconda\envs\py38\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)

# %%
# !pip install --upgrade moviepy
# !pip install torch torchvision torchaudio
import json
import os
from moviepy.editor import *
from moviepy import *
import numpy as np
from PIL import Image
# Out:
# Requirement already satisfied: moviepy in f:\anaconda\envs\py38\lib\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (1.24.3)
# Requirement already satisfied: imageio<3.0,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (2.32.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in f:\anaconda\envs\py38\lib\site-packages (from moviepy) (0.4.9)
# Collecting pillow<10.1.0,>=8.3.2 (from imageio<3.0,>=2.5->moviepy)
#   Obtaining dependency information for pillow<10.1.0,>=8.3.2 from https://files.pythonhosted.org/packages/c9/b6/2f5559c68deb840715b8f8bf1f33c75e02339aa3e5725d82775b9325d4af/Pillow-10.0.1-cp38-cp38-win_amd64.whl.metadata
#   Using cached Pillow-10.0.1-cp38-cp38-win_amd64.whl.metadata (9.6 kB)
# Requirement already satisfied: setuptools in f:\anaconda\envs\py38\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (68.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\envs\py38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2023.7.22)
# Requirement already satisfied: colorama in f:\anaconda\envs\py38\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# Using cached Pillow-10.0.1-cp38-cp38-win_amd64.whl (2.5 MB)
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 10.1.0
#     Uninstalling Pillow-10.1.0:
#       Successfully uninstalled Pillow-10.1.0
# Successfully installed pillow-10.0.1
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# Requirement already satisfied: torch in f:\anaconda\envs\py38\lib\site-packages (2.1.0)
# Requirement already satisfied: torchvision in f:\anaconda\envs\py38\lib\site-packages (0.16.0)
# Requirement already satisfied: torchaudio in f:\anaconda\envs\py38\lib\site-packages (2.1.0)
# Requirement already satisfied: filelock in f:\anaconda\envs\py38\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in f:\anaconda\envs\py38\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in f:\anaconda\envs\py38\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in f:\anaconda\envs\py38\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in f:\anaconda\envs\py38\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in f:\anaconda\envs\py38\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in f:\anaconda\envs\py38\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in f:\anaconda\envs\py38\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in f:\anaconda\envs\py38\lib\site-packages (from torchvision) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda\envs\py38\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\envs\py38\lib\site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in f:\anaconda\envs\py38\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\envs\py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (f:\anaconda\envs\py38\lib\site-packages)

# %%
import os

current_path = os.getcwd()
print(current_path)

new_path = r"C:\Users\user\Desktop\images"
os.chdir(new_path)

updated_path = os.getcwd()
print("newpath:", updated_path)
# Out:
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch
# newpath: C:\Users\user\Desktop\images

# %%
# %cd C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\video-classification-3d-cnn-pytorch
# Out:
# C:\Users\user\Desktop\video-classification-3d-cnn-pytorch\video-classification-3d-cnn-pytorch

# %%
from moviepy.editor import VideoFileClip
import os
import numpy as np
import tensorflow as tf


def load_image(img_file, target_size=(224, 224)):
    X = np.zeros((1, *target_size, 3))
    X[0, ] = np.asarray(tf.keras.preprocessing.image.load_img(
        img_file,
        target_size=target_size)
    )
    X = tf.keras.applications.mobilenet.preprocess_input(X)
    return X

def ensure_folder_exists(folder):
    if not os.path.exists(folder):
        os.makedirs(folder)

model = tf.keras.applications.mobilenet.MobileNet(
    input_shape=(224, 224, 3),
    include_top=False,
    pooling='avg'
)

# %%
XVideo = VideoFileClip(r"C:\\Users\\user\\Desktop\\Input_films\\kind-of-work-girls-do.mp4")
frames_directory = "C:\\Users\\user\\Desktop\\frames"
for i in range(int(XVideo.duration)):
    frameX = XVideo.get_frame(i)
    filename = f"{i}.jpg"
    
    try:
        img = Image.fromarray(frameX)
        img.save(os.path.join(frames_directory, filename), "JPEG")
    except Exception as e:
        print(f"Error: {str(e)}")

# %%
def opF(path):
    p = Path(path)
    
inputX_Path = "C:\\Users\\user\\Desktop\\images\\R.jpg"
opF(inputX_Path)

inputX_image = load_image(inputX_Path)
featureinputX = model.predict(inputX_image)[0]
# Out:
# 1/1 [==============================] - 0s 365ms/step

# %%
featureFrames = []
for i in range(int(XVideo.duration)):
    Frames_images_Path = f"C:\\Users\\user\\Desktop\\frames\\{str(i)}.jpg"
    opF(Frames_images_Path)
    Frames_images = load_image(Frames_images_Path)
    featureFrames_images = model.predict(Frames_images)[0]
    featureFrames.append(featureFrames_images)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
distances = []
for i, s in enumerate(featureFrames):
    distanceX = np.linalg.norm(s - featureinputX)
    distances.append((i, distanceX))

distances.sort(key=lambda x: x[1], reverse=False)
print(distances[0])
# Out:
# (8, 28.887165)

# %%
from moviepy.editor import VideoFileClip
from IPython.display import display, Image
from PIL import Image as PILImage
import io

video_path = r"C:\\Users\\user\\Desktop\\Input_films\\kind-of-work-girls-do.mp4"
video_clip = VideoFileClip(video_path)
target_time = 7  
frame_at_target_time = video_clip.get_frame(target_time)

image_path = "frame_at_target_time.png"
pil_image = PILImage.fromarray(frame_at_target_time)
pil_image.save(image_path)
display(Image(filename=image_path))
video_clip.close()

# %%
print(distances[:20])
# Out:
# [(8, 28.887165), (5, 29.282438), (4, 29.891764), (3, 30.144297), (2, 30.929628), (7, 31.745947), (6, 31.96536), (0, 32.707222), (1, 33.80314)]

# %%
tf.keras.preprocessing.image.load_img(inputX_Path, target_size=(224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
from moviepy.editor import VideoFileClip

videoX = VideoFileClip(r"C:\\Users\\user\\Desktop\\Input_films\\kind-of-work-girls-do.mp4")
subVideo = videoX.subclip(2, 6)
subVideo.write_videofile("C:\\Users\\user\\Desktop\\output_films\\new01.mp4", codec='libx264', audio_codec='aac')
# Out:
# Moviepy - Building video C:\Users\user\Desktop\output_films\new01.mp4.
# MoviePy - Writing audio in new01TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video C:\Users\user\Desktop\output_films\new01.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\user\Desktop\output_films\new01.mp4
